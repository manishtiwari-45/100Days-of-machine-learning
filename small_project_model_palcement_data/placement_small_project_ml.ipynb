# %% [markdown]
# # STEPS
#
#  1. Preprocess + EDA + Feature Selection
#  2. Extract input and output columns
#  3. Scale the values
#  4. Train test split
#  5. Train the model
#  6. Evaluate the model/model selection
#  7. Deploy the model

# %%
import numpy as numpy
import pandas as pd

# %%
df = pd.read_csv('placement-dataset.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df = df.iloc[:,1:]

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['cgpa'],df['iq'],c = df['placement'])

# %%
x = df.iloc[:,0:2] #input
y = df.iloc[:,-1]  #output

# %% [markdown]
# Train test split

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.1)

# %% [markdown]
# scaling

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
x_train = scaler.fit_transform(x_train)

# %%
x_train
# Out:
# array([[-0.79452839, -1.45955917],
#        [ 1.3009311 ,  0.21615556],
#        [ 0.86437704,  0.45180295],
#        [-0.00873108, -2.00940307],
#        [-0.27066352,  1.23729423],
#        [ 0.51513379,  0.42561991],
#        [ 0.68975541,  0.50416903],
#        [-1.23108245,  0.63508425],
#        [-0.8818392 , -0.09804095],
#        [ 0.86437704,  1.39439249],
#        [ 0.95168785,  0.76599946],
#        [-0.00873108, -1.45955917],
#        [ 1.99941759,  1.21111119],
#        [ 1.12630947, -0.93589832],
#        [-0.79452839,  0.16378948],
#        [-0.27066352,  0.55653512],
#        [ 0.42782298,  1.00164685],
#        [ 0.34051217,  0.50416903],
#        [-0.70721758,  0.26852165],
#        [ 0.07857973,  0.89691467],
#        [ 1.56286353, -0.20277312],
#        [ 0.25320135,  0.13760644],
#        [ 1.38824191, -0.85734919],
#        [-0.00873108,  0.71363338],
#        [ 0.77706622, -0.67406789],
#        [ 1.3009311 , -1.59047438],
#        [ 0.42782298, -2.21886741],
#        [-0.96915001,  0.32088773],
#        [-1.14377163, -0.90971527],
#        [-1.14377163, -1.82612177],
#        [-1.05646082,  1.08019597],
#        [ 0.6024446 ,  1.57767379],
#        [ 0.86437704, -0.25513921],
#        [-0.53259595, -0.38605442],
#        [ 1.38824191,  0.16378948],
#        [-2.19150137,  2.91300896],
#        [ 0.34051217, -0.15040703],
#        [ 0.25320135,  0.16378948],
#        [-0.8818392 , -0.8049831 ],
#        [ 0.16589054, -0.22895616],
#        [-0.27066352,  0.26852165],
#        [-0.96915001, -1.59047438],
#        [-1.05646082, -0.25513921],
#        [ 0.42782298,  0.21615556],
#        [-0.53259595,  0.45180295],
#        [-0.70721758, -0.30750529],
#        [-0.96915001,  0.76599946],
#        [ 0.07857973,  0.26852165],
#        [ 0.86437704, -1.51192526],
#        [ 0.68975541,  0.03287426],
#        [ 1.21362028,  0.26852165],
#        [-1.49301488,  2.04896855],
#        [ 0.51513379, -0.04567486],
#        [-1.40570407,  0.71363338],
#        [ 0.42782298, -0.83116615],
#        [ 1.12630947,  0.39943686],
#        [ 1.3009311 ,  0.94928076],
#        [-0.53259595, -0.20277312],
#        [ 0.6024446 ,  0.84454859],
#        [-1.14377163, -0.01949182],
#        [ 1.82479597,  1.1587451 ],
#        [-0.53259595,  0.34707078],
#        [-2.366123  ,  1.60385683],
#        [ 0.25320135, -0.49078659],
#        [-0.00873108, -0.51696963],
#        [-0.1833527 ,  1.1587451 ],
#        [ 0.77706622,  0.42561991],
#        [ 0.77706622,  0.45180295],
#        [-0.27066352,  0.47798599],
#        [-1.05646082,  0.50416903],
#        [-0.96915001, -0.04567486],
#        [ 1.73748515, -1.11917962],
#        [ 0.68975541, -0.83116615],
#        [-1.75494732, -0.56933572],
#        [-0.61990676, -0.20277312],
#        [ 2.17403921, -0.04567486],
#        [-0.96915001,  1.94423638],
#        [-0.8818392 , -1.5381083 ],
#        [ 0.07857973, -1.48574221],
#        [ 1.82479597,  0.71363338],
#        [ 0.07857973, -1.06681353],
#        [ 0.95168785, -1.93085394],
#        [ 0.68975541, -0.25513921],
#        [-1.40570407, -2.0879522 ],
#        [-1.05646082,  1.23729423],
#        [-0.09604189, -0.41223746],
#        [-0.00873108,  0.05905731],
#        [-1.75494732, -1.22391179],
#        [-0.70721758, -0.83116615],
#        [-0.96915001,  0.87073163]])

# %%
x_test = scaler.transform(x_test)

# %%
x_test
# Out:
# array([[ 1.12630947, -0.15040703],
#        [-1.84225813, -0.33368833],
#        [-0.70721758,  1.02782989],
#        [-0.61990676, -0.01949182],
#        [ 1.12630947, -1.87848785],
#        [-0.70721758,  2.67736158],
#        [ 0.07857973, -0.49078659],
#        [ 0.86437704,  2.02278551],
#        [-0.79452839,  1.42057553],
#        [-0.1833527 ,  0.53035208]])

# %% [markdown]
# model training

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression()

# %%
# model training
clf.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = clf.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9

# %% [markdown]
# plot decision boundary

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x_train,y_train.values,clf=clf,legend=2)
# Out:
# <Axes: >

# %%
import pickle

# %%
pickle.dump(clf,open('model.pkl','wb'))
